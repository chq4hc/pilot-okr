# %%
import os
from agents import PlanningSession, TimeFrame
from dataclasses import dataclass, field

@dataclass
class LLMConfig:
    """Configuration for LLM API connection."""
    api_key: str = "sk-bgsv-ai-team"
    base_url: str = "https://sx-bgsv-llm.agreeablerock-77e2087d.southeastasia.azurecontainerapps.io/"
    model: str = "azure-gpt-5"
    temperature: float = 1.0
    max_tokens: int = 2000
    timeout: int = 30

# %%
config_ = LLMConfig()
# Create a planning session
session = PlanningSession(config=config_)

# Start planning for Engineering department
result = session.start(
    department_name="Engineering",
    strategic_goals=[
        "Scale platform to support 1 million concurrent users",
        "Improve system reliability and uptime to 99.99%",
        "Reduce technical debt by 30%",
        "Enhance developer productivity and CI/CD pipeline"
    ],
    timeframe=TimeFrame.Q2,
    team_size=25,
    budget=500000.0,
    focus_areas=[
        "Infrastructure scalability",
        "Performance optimization",
        "Code quality",
        "Developer experience"
    ],
    constraints=[
        "Limited hiring budget",
        "Must maintain backwards compatibility",
        "Zero downtime deployments required"
    ],
    company_okrs=[
        "Achieve $10M ARR",
        "Expand to 3 new markets",
        "Reach 95% customer satisfaction"
    ],
    num_epics=3,
    num_objectives_per_epic=3
)

# Print summary
print("\n" + "="*60)
print("Planning Session Complete!")
print("="*60)
session.print_summary()
# Out:
# 🚀 Starting planning session for Engineering
#    Timeframe: Q2
#
# 📋 Step 1: Generating 3 epics...
#    ✓ Generated 3 epics
#
# 🎯 Step 2: Prioritizing epics...
#
# 📊 Step 3: Generating OKRs for each epic...
#    Processing Epic 1/3: Multi-Region Autoscaling to Support 1M Concurrent Users
#    ✓ Added 3 objectives with 14 key results
#    Processing Epic 2/3: Reliability & Zero-Downtime Delivery: Achieve 99.99% Uptime
#    ✓ Added 3 objectives with 12 key results
#    Processing Epic 3/3: Technical Debt Reduction & Developer Experience Upgrade (30%)
#    ✓ Added 3 objectives with 13 key results
#
# ✅ Planning session complete!
#    Total: 3 epics, 9 objectives, 39 key results
#
# ============================================================
# Planning Session Complete!
# ============================================================
#
# ============================================================
# Planning Summary: Engineering
# ============================================================
# Timeframe: Q2
# Total Epics: 3
# Total Objectives: 9
# Total Key Results: 39
#
# Epics:
#
#   [CRITICAL] Multi-Region Autoscaling to Support 1M Concurrent Users
#   ID: epic-001 | Objectives: 3 | Progress: 0.0%
#
#   [CRITICAL] Reliability & Zero-Downtime Delivery: Achieve 99.99% Uptime
#   ID: epic-002 | Objectives: 3 | Progress: 0.0%
#
#   [HIGH] Technical Debt Reduction & Developer Experience Upgrade (30%)
#   ID: epic-003 | Objectives: 3 | Progress: 0.0%
#
# ============================================================

# %%
print("\n📄 Exporting results...")
output_filename = "planning_result.json"
OUTPUT_FNAME = os.path.join(os.getcwd(), "data", "output", output_filename)
session.export(OUTPUT_FNAME, format="json")
print("✓ Exported to planning_result.json and planning_result.md")

# %%
# Example: Refine an epic based on feedback
if result.epics:
    print("\n🔄 Example: Refining first epic...")
    epic_id = result.epics[0].id
    feedback = """
    Please adjust this epic to:
    1. Include more specific performance metrics
    2. Add monitoring and observability as key components
    3. Consider cost optimization alongside performance
    """
    
    refined_result = session.refine_epic(epic_id, feedback)
    print(f"✓ Refined epic: {refined_result.epics[0].title}")
    
    # Export refined version
    session.export("planning_result_refined.json", format="json")
    print("✓ Exported refined version")

# Display detailed epic information
print("\n" + "="*60)
print("Detailed Epic Information")
print("="*60)

for i, epic in enumerate(result.epics, 1):
    print(f"\n{'─'*60}")
    print(f"Epic {i}: {epic.title}")
    print(f"{'─'*60}")
    print(f"Priority: {epic.priority.value.upper()}")
    print(f"Estimated Effort: {epic.estimated_effort}")
    print(f"Progress: {epic.overall_progress:.1f}%")
    print(f"\nDescription:")
    print(f"  {epic.description}")
    print(f"\nBusiness Value:")
    print(f"  {epic.business_value}")
    
    if epic.dependencies:
        print(f"\nDependencies:")
        for dep in epic.dependencies:
            print(f"  - {dep}")
    
    if epic.stakeholders:
        print(f"\nStakeholders:")
        for stakeholder in epic.stakeholders:
            print(f"  - {stakeholder}")
    
    print(f"\nObjectives ({len(epic.objectives)}):")
    for j, obj in enumerate(epic.objectives, 1):
        print(f"\n  {j}. {obj.title}")
        print(f"     Priority: {obj.priority.value} | Progress: {obj.overall_progress:.1f}%")
        print(f"     {obj.description}")
        
        print(f"\n     Key Results ({len(obj.key_results)}):")
        for k, kr in enumerate(obj.key_results, 1):
            progress_bar = "█" * int(kr.progress_percentage / 10) + "░" * (10 - int(kr.progress_percentage / 10))
            print(f"       {k}. {kr.description}")
            print(f"          Metric: {kr.metric}")
            print(f"          Target: {kr.baseline} → {kr.target} {kr.unit}")
            print(f"          Progress: [{progress_bar}] {kr.progress_percentage:.1f}%")
            if kr.owner:
                print(f"          Owner: {kr.owner}")

print("\n" + "="*60)
print("✅ Planning session example complete!")
print("="*60)
# Out:
# 🔄 Example: Refining first epic...
# 🔄 Refining epic: Multi-Region Autoscaling to Support 1M Concurrent Users
# 📊 Regenerating OKRs...
# ✓ Refinement complete
# ✓ Refined epic: Multi-Region Autoscaling to Support 1M Concurrent Users
# ✓ Exported to planning_result_refined.json
# ✓ Exported refined version
#
# ============================================================
# Detailed Epic Information
# ============================================================
#
# ────────────────────────────────────────────────────────────
# Epic 1: Multi-Region Autoscaling to Support 1M Concurrent Users
# ────────────────────────────────────────────────────────────
# Priority: CRITICAL
# Estimated Effort: 30 person-months
# Progress: 0.0%
#
# Description:
#   Design, implement, and validate a horizontally scalable, multi-region architecture capable of sustaining 1 million concurrent users with zero-downtime and backward compatibility. Deliver global load balancing, autoscaling policies, CDN tuning, stateless service patterns, session management, and database read-replicas/partitioning. Execute capacity planning and large-scale load tests to verify performance targets. Introduce feature flags to ensure backward compatibility during rollout. SMART outcomes by end of Q2: (1) Demonstrate sustained 1M concurrent users in pre-prod with p95 latency ≤ 250ms and error rate ≤ 0.1%; (2) Production-ready multi-region failover with recovery time ≤ 2 minutes in controlled drills; (3) Documented runbooks and readiness checks to enter 3 new markets; (4) Changes delivered with zero downtime using canary/blue-green in coordination with the reliability pipeline.
#
# Business Value:
#   Unlocks growth and market expansion by enabling the platform to handle peak demand, directly supporting $10M ARR and entry into 3 new markets. Faster, more reliable performance reduces churn and increases customer satisfaction toward 95%.
#
# Dependencies:
#   - epic-002: Reliability & Zero-Downtime Delivery
#   - Cloud provider quota increases and multi-region account setup
#   - Database partitioning/read-replica strategy approved
#   - Security and compliance review for data residency and traffic routing
#   - Observability coverage for capacity testing
#
# Stakeholders:
#   - CTO
#   - Head of Engineering
#   - SRE Lead
#   - DevOps Lead
#   - Database Architect
#   - Product Management
#   - Security Lead
#
# Objectives (3):
#
#   1. Prove 1M-concurrency, low-latency performance across regions without errors
#      Priority: critical | Progress: 0.0%
#      Demonstrate our platform can sustain 1,000,000 concurrent users globally with fast response times and high quality, validating the multi-region autoscaling architecture in pre-production.
#
#      Key Results (4):
#        1. Sustain 1,000,000 concurrent users in pre-production for at least 30 minutes of steady-state load
#           Metric: Sustained concurrent users (pre-prod, 30-min steady state)
#           Target: 300000.0 → 1000000.0 users
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Performance Engineering Team
#        2. Reduce p95 latency at 1M concurrency in pre-production to ≤ 250 ms
#           Metric: p95 latency at 1M concurrent (pre-prod)
#           Target: 420.0 → 250.0 ms
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Performance Engineering Team
#        3. Lower HTTP error rate (4xx/5xx) at peak load to ≤ 0.1% during pre-production scale test
#           Metric: HTTP error rate at peak load (4xx/5xx)
#           Target: 1.5 → 0.1 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: SRE Team
#        4. Increase share of read traffic served by replicas/partitions at peak load to improve performance
#           Metric: Read traffic served by replicas/partitions
#           Target: 55.0 → 90.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Database Engineering Team
#
#   2. Achieve production-ready multi-region resilience with lightning-fast failover
#      Priority: critical | Progress: 0.0%
#      Harden global reliability with automated failover, accurate traffic steering, and operational readiness to meet 99.99% uptime and expand into new markets.
#
#      Key Results (4):
#        1. Reduce average recovery time objective (RTO) in controlled multi-region failover drills to ≤ 2.0 minutes
#           Metric: Average failover RTO (controlled drills)
#           Target: 7.0 → 2.0 minutes
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: SRE Team
#        2. Increase controlled failover drill pass rate (no data loss, SLOs met) to ≥ 95%
#           Metric: Failover drill pass rate (no data loss, SLO met)
#           Target: 60.0 → 95.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: SRE Team
#        3. Improve global load balancing to route ≥ 95% of requests to the nearest healthy region
#           Metric: Requests routed to nearest healthy region
#           Target: 80.0 → 95.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Networking & Edge Team
#        4. Complete and sign off runbooks and readiness checks for launching in 3 new markets
#           Metric: Markets with signed-off runbooks and readiness checks
#           Target: 0.0 → 3.0 markets
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: SRE Team
#
#   3. Accelerate safe adoption with autoscaling, stateless services, CDN tuning, and zero-downtime delivery
#      Priority: critical | Progress: 0.0%
#      Enable fast, reliable rollout and developer velocity by optimizing autoscaling, externalizing sessions, tuning CDN, and enforcing canary/blue-green for seamless releases.
#
#      Key Results (5):
#        1. Achieve zero-downtime deployment rate ≥ 95% using canary/blue-green in the reliability pipeline
#           Metric: Zero-downtime deployment rate
#           Target: 75.0 → 95.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Release Engineering Team
#        2. Improve autoscaling responsiveness: reduce median scale-out time to add 100 instances under load to ≤ 2 minutes
#           Metric: Median scale-out time to add 100 instances under load
#           Target: 8.0 → 2.0 minutes
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Platform Engineering Team
#        3. Expand stateless service adoption: increase services with externalized session management to 85%
#           Metric: Services stateless with externalized sessions
#           Target: 40.0 → 85.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Application Platform Team
#        4. Boost global CDN effectiveness: increase cache hit ratio to 90%
#           Metric: Global CDN cache hit ratio
#           Target: 65.0 → 90.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Networking & Edge Team
#        5. Increase feature flag coverage: ensure 90% of changed services are guarded to maintain backward compatibility
#           Metric: Changed services guarded by feature flags
#           Target: 30.0 → 90.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Release Engineering Team
#
# ────────────────────────────────────────────────────────────
# Epic 2: Reliability & Zero-Downtime Delivery: Achieve 99.99% Uptime
# ────────────────────────────────────────────────────────────
# Priority: CRITICAL
# Estimated Effort: 25 person-months
# Progress: 0.0%
#
# Description:
#   Establish and operationalize service-level objectives (SLOs), error budgets, and robust observability to achieve 99.99% uptime with zero-downtime deployments. Implement end-to-end monitoring (metrics, logs, traces), automated alerts, canary and blue/green strategies, rollout safeguards, and chaos drills. Update disaster recovery and backup procedures; create incident runbooks and refine on-call processes. SMART outcomes by end of Q2: (1) Monthly uptime ≥ 99.99%; (2) MTTR ≤ 30 minutes for P1 incidents; (3) Change failure rate ≤ 5% with automated rollback; (4) Canary/blue-green used for 100% of production deployments; (5) Observability coverage ≥ 95% of critical services.
#
# Business Value:
#   Higher reliability and zero-downtime deployments improve customer trust and satisfaction, directly supporting the 95% CSAT target and ARR retention while reducing incident costs and risk during market expansion.
#
# Dependencies:
#   - Access to production telemetry and logging endpoints
#   - On-call roster and training finalized
#   - Budget approval for monitoring/incident tooling (≤ $150k within existing budget)
#   - Change management policy updates and security review
#   - Coordination with QA for automated quality gates
#
# Stakeholders:
#   - CTO
#   - Head of Engineering
#   - SRE Lead
#   - DevOps Lead
#   - QA Lead
#   - Security Lead
#   - Customer Support Lead
#   - Product Management
#
# Objectives (3):
#
#   1. Make reliability visible: SLOs, error budgets, and 360° observability powering four‑nines
#      Priority: critical | Progress: 0.0%
#      Operationalize SLOs and error budgets and achieve robust, end‑to‑end observability so teams can detect, triage, and resolve issues fast enough to consistently deliver 99.99% uptime.
#
#      Key Results (4):
#        1. Monthly aggregate service availability meets four‑nines SLO
#           Metric: Monthly service availability (SLO)
#           Target: 99.95 → 99.99 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: SRE Lead
#        2. Reduce mean time to recover (MTTR) for P1 incidents
#           Metric: P1 incident MTTR
#           Target: 75.0 → 30.0 minutes
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Incident Response Lead
#        3. Expand observability coverage across critical services (metrics, logs, traces, dashboards, SLOs)
#           Metric: Observability coverage of critical services
#           Target: 70.0 → 95.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Observability Team Lead
#        4. Shorten mean time to acknowledge (MTTA) for P1 alerts via actionable alerts and routing
#           Metric: P1 alert MTTA
#           Target: 9.0 → 3.0 minutes
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: On-Call Lead
#
#   2. Ship without fear: zero‑downtime releases through progressive delivery and smart safeguards
#      Priority: critical | Progress: 0.0%
#      Adopt canary and blue/green strategies with automated safeguards and rollback to ensure every production change is safe, observable, and delivers zero customer‑visible downtime.
#
#      Key Results (4):
#        1. Use canary or blue/green for all production deployments
#           Metric: Production deployments using canary/blue-green
#           Target: 35.0 → 100.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Release Engineering Lead
#        2. Lower change failure rate across production deployments
#           Metric: Change failure rate
#           Target: 12.0 → 5.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: DevOps Lead
#        3. Reduce mean time to automated rollback after a failed deployment
#           Metric: Mean time to automated rollback
#           Target: 15.0 → 5.0 minutes
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: CI/CD Automation Lead
#        4. Increase proportion of releases with zero customer‑visible downtime
#           Metric: Deployments with zero downtime
#           Target: 96.0 → 99.9 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Platform Engineering Manager
#
#   3. Recover fast, fail safe: drill‑ready resilience, backups, and failover you can trust
#      Priority: critical | Progress: 0.0%
#      Strengthen disaster recovery, backup integrity, and incident readiness with practiced failover and runbooks so critical services recover rapidly and reliably under stress.
#
#      Key Results (4):
#        1. Reduce regional failover time (RTO) to the secondary region
#           Metric: Regional failover RTO
#           Target: 60.0 → 15.0 minutes
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Infrastructure Reliability Lead
#        2. Increase verified backup restore success rate for critical data stores
#           Metric: Backup restore success rate (critical stores)
#           Target: 80.0 → 99.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Data Platform Lead
#        3. Increase proportion of P1 incidents detected by automated monitoring rather than customer reports
#           Metric: Automated detection rate for P1 incidents
#           Target: 70.0 → 95.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Monitoring Lead
#        4. Achieve complete, up‑to‑date incident runbooks for all P1 services
#           Metric: Incident runbook coverage (P1 services)
#           Target: 50.0 → 100.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: SRE Documentation Lead
#
# ────────────────────────────────────────────────────────────
# Epic 3: Technical Debt Reduction & Developer Experience Upgrade (30%)
# ────────────────────────────────────────────────────────────
# Priority: HIGH
# Estimated Effort: 20 person-months
# Progress: 0.0%
#
# Description:
#   Execute a targeted program to reduce high-impact technical debt while improving CI/CD and developer workflows without additional hiring. Prioritize the top 20 debt items affecting reliability and performance; refactor legacy modules with backward-compatible APIs; raise automated test coverage; enforce linting/static analysis; and optimize CI with caching, parallelization, and trunk-based workflows. SMART outcomes by end of Q2: (1) Reduce code quality debt by 30% in prioritized services (e.g., code smells −30%, cyclomatic complexity −20%); (2) Increase unit/integration test coverage by +15 percentage points in core services; (3) Cut CI pipeline time by 40% (e.g., from 25 min to ≤ 15 min); (4) Increase deployment frequency by 50% and reduce lead time for changes to ≤ 1 day; (5) All changes released with zero downtime and maintained backward compatibility.
#
# Business Value:
#   Improves developer productivity and delivery speed, accelerating market expansion and feature velocity to support $10M ARR. Reduced defects and faster pipelines elevate customer satisfaction and lower maintenance costs.
#
# Dependencies:
#   - Code ownership map and debt triage completed
#   - Quality gates configured in CI (test coverage and static analysis)
#   - Feature flag framework in place for safe refactors
#   - Product alignment on refactor windows to avoid customer impact
#   - Coordination with DevOps for CI resource scaling
#
# Stakeholders:
#   - Head of Engineering
#   - Engineering Managers
#   - Tech Leads
#   - DevOps Lead
#   - QA Lead
#   - Product Management
#
# Objectives (3):
#
#   1. Retire critical technical debt with safe, backward-compatible refactors
#      Priority: high | Progress: 0.0%
#      Eliminate the highest-impact debt in prioritized services to boost reliability and performance while maintaining backward-compatible APIs.
#
#      Key Results (4):
#        1. Reduce code quality debt in prioritized services by cutting code smells by 30%
#           Metric: SonarQube Code Smells (prioritized services)
#           Target: 1200.0 → 840.0 issues
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Engineering Platform Team
#        2. Lower average cyclomatic complexity in legacy modules by 20%
#           Metric: Average Cyclomatic Complexity (per function, legacy modules)
#           Target: 12.0 → 9.6 complexity score
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Architecture Guild
#        3. Resolve the top 20 prioritized debt items with backward-compatible APIs
#           Metric: Debt Items Resolved (with backward-compatible APIs)
#           Target: 0.0 → 20.0 items
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Engineering Platform Team
#        4. Achieve zero backward-compatibility break incidents in production
#           Metric: Backward Compatibility Break Incidents (production)
#           Target: 2.0 → 0.0 incidents
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Release Engineering
#
#   2. Make tests a safety net: expand coverage and tighten quality gates
#      Priority: high | Progress: 0.0%
#      Strengthen automated testing and static analysis so issues are caught early, improving system reliability and developer confidence.
#
#      Key Results (4):
#        1. Increase unit test coverage in core services by +15 percentage points
#           Metric: Core Services Unit Test Coverage (statement)
#           Target: 55.0 → 70.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: QA Automation Team
#        2. Increase integration test coverage in core services by +15 percentage points
#           Metric: Core Services Integration Test Coverage
#           Target: 40.0 → 55.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: QA Automation Team
#        3. Reduce static analysis/lint warnings across prioritized repos by 50%
#           Metric: Static Analysis/Lint Warnings (aggregated across prioritized repos)
#           Target: 800.0 → 400.0 warnings
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Engineering Platform Team
#        4. Raise first-pass CI quality gate success rate for PRs
#           Metric: PRs Passing CI Quality Gates on First Attempt
#           Target: 72.0 → 95.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: QA Automation Team
#
#   3. Turbocharge CI/CD to ship faster with zero-downtime releases
#      Priority: high | Progress: 0.0%
#      Optimize pipelines with caching and parallelization, adopt trunk-based workflows, and improve deployment practices to deliver quickly and safely.
#
#      Key Results (5):
#        1. Cut median CI pipeline time by 40%
#           Metric: Median CI Pipeline Duration (build + test)
#           Target: 25.0 → 15.0 minutes
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: DevOps & Release Engineering
#        2. Increase production deployment frequency by 50%
#           Metric: Deployment Frequency (production deployments per month)
#           Target: 20.0 → 30.0 deployments/month
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: DevOps & Release Engineering
#        3. Reduce median lead time for changes to ≤ 1 day
#           Metric: Median Lead Time for Changes (commit to production)
#           Target: 2.5 → 1.0 days
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Engineering Platform Team
#        4. Achieve 100% zero-downtime release rate
#           Metric: Zero-Downtime Release Rate (production)
#           Target: 96.0 → 100.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: SRE Team
#        5. Adopt trunk-based workflow across prioritized repos
#           Metric: Repos Using Trunk-Based Workflow (protected main, short-lived branches)
#           Target: 30.0 → 80.0 %
#           Progress: [░░░░░░░░░░] 0.0%
#           Owner: Engineering Platform Team
#
# ============================================================
# ✅ Planning session example complete!
# ============================================================
